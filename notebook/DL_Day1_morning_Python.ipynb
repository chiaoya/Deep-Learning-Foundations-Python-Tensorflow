# %% [markdown]
# # 10:30–11:30 | Python-Grundlagen

# %% [markdown]
# ## **Dein erstes Python Programm**
#
# **Ziel:** Die Teilnehmenden lernen, wie man mit `print()` Text und Rechenergebnisse ausgibt.
#
# - print “Hello World!”
# - Operators and print results

# %% [markdown]
# ## 🧩 Hello World!

# %%
# Schreibe dein erstes Programm!
print("Hello World!")
print("Herzlich willkommen zum Python-Kurs!")
# Out:
# Hello World!
# Herzlich willkommen zum Python-Kurs!

# %% [markdown]
# ### Übung:
#
# - Gib mit print() deinen Namen aus
# → **Beispiel:** print("Mein Name ist …")
#
# - Gib mit print() einen kurzen Satz aus, der deinen ersten Eindruck von Deep Learning beschreibt
# → **Beispiel:**
# print("Deep Learning klingt spannend, aber auch ein bisschen komplex.")

# %% [markdown]
# ## 🧩 Operatoren ausprobieren

# %%
# Verwende +, -, *, /, % (Rest) und ** (Potenz)
print("3 + 2 =", 3 + 2)
print("10 - 4 =", 10 - 4)
print("6 * 7 =", 6 * 7)
# / (Division) → normale Division, Ergebnis ist immer eine Dezimalzahl (Float)
print("8 / 2 =", 8 / 2)
# // (Ganzzahl-Division) → teilt und rundet das Ergebnis nach unten ab
print("8 // 2 =", 8 // 2)
# % (Modulo) → gibt den Rest der Division zurück
print("10 % 3 =", 10 % 3)
# ** Potenz (Exponent) → also 2 hoch 3
print("2 ** 3 =", 2 ** 3)
# Out:
# 3 + 2 = 5
# 10 - 4 = 6
# 6 * 7 = 42
# 8 / 2 = 4.0
# 8 // 2 = 4
# 10 % 3 = 1
# 2 ** 3 = 8

# %% [markdown]
# ### Übung:
#
# - Gib mit print() "9 / 2" und "9 // 2" und "9 % 2" aus und erklären den Unterschied.
#
# - Rechnen mit Klammern (7 + (2 * 9)) // 5
#
# - Füge eigenen Text hinzu oder kombiniere mehrere Berechnungen in einer Zeile.
#
# **Merke**
#
# - Klammern bestimmen die Reihenfolge
# - und * und / werden vor + und - ausgeführt
#
# - // und % sind besonders nützlich für Zählprobleme, Aufteilungen und Indizes

# %% [markdown]
# # **Variables**
#
# **Ziel:** Verstehen, wie Informationen gespeichert und mit Text kombiniert werden.
#
# - Dein Info (Name: string, Beruf: string, Alter: Integer, Kinder: boolean, Jahre der Beruferfahrung: float)
# - Variablen erstellen und print text verbunden mit der Variablen
# - If-Else-Verzweigung

# %% [markdown]
# ## 🧩 Persönliche Daten und Datentypen in Python (Data Types)

# %%
# Erstelle Variablen zu dir selbst

# Text (String)
name = "Alex"
beruf = "Data Scientist"

# Ganze Zahl (Integer)
alter = 32

# Wahrheitswert (Boolean)
kinder = False

# Dezimalzahl (Float)
erfahrung = 5.5

print("Mein Name ist", name)
print("Ich arbeite als", beruf, "und habe", erfahrung, "Jahre Erfahrung.")
# Leere Zeile
print("")
# oder
print("oder")
# Leere Zeile
print("")
print("Mein Name ist " + name + ". " + "Ich bin " + str(alter) + " Jahre alt und habe " + str(erfahrung) + " Jahre Erfahrung. " + "Ich arbeite als " + beruf + ". " + "Habe ich Kinder? " + str(kinder))
# Out:
# Mein Name ist Alex
# Ich arbeite als Data Scientist und habe 5.5 Jahre Erfahrung.
#
# oder
#
# Mein Name ist Alex. Ich bin 32 Jahre alt und habe 5.5 Jahre Erfahrung. Ich arbeite als Data Scientist. Habe ich Kinder? False

# %% [markdown]
# ### Übung: Bitte einen kurzen Text mit Erstellung der Variablen über dich schreiben und print().
#
# name = "Max"
#
# alter = 35
#
# stadt = "Berlin"
#
# interesse = "Künstliche Intelligenz"
#
# lernt_python = True
#
# print(
#   "Mein Name ist " + name + ". "
#   + "Ich bin " + str(alter) + " Jahre alt. "
#   + "Ich lebe in " + stadt + ". "
#   + "Mein Interesse ist " + interesse + ". "
#   + "Lerne ich gerade Python? " + str(lernt_python)
#   )

# %% [markdown]
# ## 🧩 If-Else-Verzweigung

# %%
# Prüfe, ob jemand berufserfahren ist
if erfahrung > 3:
    print(name, "ist erfahren!")
else:
    print(name, "ist noch Anfänger.")
# Out:
# Alex ist erfahren!

# %%
if alter >= 18:
    print(name, "ist volljährig.")
else:
    print(name, "ist minderjährig.")
# Out:
# Alex ist volljährig.

# %% [markdown]
# ### Übung:
#
# Erstelle eine If-Else-Verzweigung, die überprüft, ob eine Person Kinder hat.
#
# - Wenn kinder ist True, gib aus: „(Name) hat Kinder.“
#
# - Wenn kinder ist False, gib aus: „(Name) hat keine Kinder.“

# %% [markdown]
# # **Loop**
#
# **Ziel:** Wiederholte Aufgaben mit for- und while-Schleifen ausführen.
#
# - For Schleife
#
# - While Schleife

# %% [markdown]
# ## 🧩 For-Schleife

# %%
# Zahlen von 0 bis 5 ausgeben
for i in range(6):
    print("Zahl:", i)
# Out:
# Zahl: 0
# Zahl: 1
# Zahl: 2
# Zahl: 3
# Zahl: 4
# Zahl: 5

# %%
# Zahlen von 1 bis 5 ausgeben
for i in range(1, 6):
    print("Zahl:", i)
# Out:
# Zahl: 1
# Zahl: 2
# Zahl: 3
# Zahl: 4
# Zahl: 5

# %% [markdown]
# **Zahlen von 0 bis einschließlich 10 mit Schrittweite 2 ausgeben**
#
# range(start, stop, step) erzeugt eine Zahlenfolge
#
# - start = 0 → Startwert
#
# - stop = 10 → 10 ist nicht enthalten
#
# - step = 2 → Schrittweite 2

# %%
# Zahlen von 0 bis einschließlich 10 mit Schrittweite 2 ausgeben
for i in range(0, 10, 2) :
    print("Zahl:", i)
# Out:
# Zahl: 0
# Zahl: 2
# Zahl: 4
# Zahl: 6
# Zahl: 8

# %%
farben = ["Rot", "Grün", "Blau"]
for farbe in farben:
    print("Ich mag die Farbe", farbe)
# Out:
# Ich mag die Farbe Rot
# Ich mag die Farbe Grün
# Ich mag die Farbe Blau

# %% [markdown]
# ### Übung:
#
# - Zahlen von 0 bis einschließlich 19 mit Schrittweite 3 ausgeben
#
# - Gibt print() mit einen Tierlist aus. List 3 Tiere, die du magst und print "Ich mag (Tier)"

# %% [markdown]
# ## 🧩 While-Schleife

# %%
# Countdown von 5 bis 1
x = 5
while x > 0:
    print("Countdown:", x)
    x -= 1 # x = x-1
print("Start!")
# Out:
# Countdown: 5
# Countdown: 4
# Countdown: 3
# Countdown: 2
# Countdown: 1
# Start!

# %%
# Zahlenraten-Spiel
zahl = 3
versuch = 0

while versuch != zahl:
    versuch = int(input("Rate eine Zahl zwischen 1 und 5: "))
    if versuch == zahl:
        print("Richtig!")
    else:
        print("Falsch, versuch es nochmal.")
# Out:
# Rate eine Zahl zwischen 1 und 5: 3
# Richtig!

# %% [markdown]
# # 🧩 **Abschlussübung – Dein persönlicher Mini-Assistent**
#
# **Ziel:** Verwende alles, was du gelernt hast: Variablen, Operatoren, If-Else, und Loops.
#
# **Dauer:** ca. 15 min
#
# ### ✅ **Aufgabe**
#
# Erstelle ein Programm, das:
#
# 1. persönliche Informationen abfragt
# 2. eine kleine Entscheidung trifft (z. B. Empfehlung oder Feedback gibt)
# 3. eine Schleife nutzt, um den Benutzer mehrfach interagieren zu lassen

# %%
# --- Beispiel: Dein persönlicher Assistent ---

print("👋 Willkommen zu deinem Mini-Assistenten!")

# 1. Eingaben
name = input("Wie heißt du? ")
alter = int(input("Wie alt bist du? "))
beruf = input("Was ist dein Beruf? ")

# 2. Bedingungen
if alter < 18:
    print("Hallo", name + "!", "Du bist noch jung – viel Spaß beim Lernen!")
elif alter < 30:
    print("Cool,", name + "!", "Ein perfektes Alter, um Python-Profi zu werden.")
else:
    print("Hi", name + "!", "Man lernt nie aus – großartig, dass du dabei bist!")

# 3. Schleife
for i in range(1,4):
    print("🤖 Runde", i, ":", name, "arbeitet als", beruf)

print("✅ Programm beendet – gute Arbeit,", name + "!")
# Out:
# 👋 Willkommen zu deinem Mini-Assistenten!
# Wie heißt du? Chiaoya
# Wie alt bist du? 31
# Was ist dein Beruf? BA
# Hi Chiaoya! Man lernt nie aus – großartig, dass du dabei bist!
# 🤖 Runde 1 : Chiaoya arbeitet als BA
# 🤖 Runde 2 : Chiaoya arbeitet als BA
# 🤖 Runde 3 : Chiaoya arbeitet als BA
# ✅ Programm beendet – gute Arbeit, Chiaoya!

# %% [markdown]
# # 11:30–12:30 | Arbeiten mit Daten (Pandas)
# Documentataion: https://pandas.pydata.org/docs/

# %% [markdown]
# ### 🔹 Lernziele
#
# Nach dieser Einheit können Teilnehmende:
#
# - Pandas importieren und ein DataFrame erstellen
# - Daten aus einer CSV-Datei laden
# - Datensätze anzeigen, filtern und einfache Berechnungen durchführen
# - Grundlegende Statistikfunktionen anwenden

# %% [markdown]
# ### **Datentabellen verstehen**
# #### Grundlage der Daten
# - Daten sind überall
# - Ohne Struktur
# - Tabellen sind der Eintrieg
#
# #### Welche Eigenschaften gibt es in einer Tabelle?

# %% [markdown]
# ### **Pandas importieren und DataFrame erstellen**

# %%
import pandas as pd

# Erstelle ein einfaches DataFrame
data = {
    "Name": ["Anna", "Ben", "Clara", "David", "Eva"],
    "Alter": [28, 35, 22, 41, 50],
    "Startjahr": [2020, 2015, 2023, 2010, 2020]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Alter  Startjahr
# 0   Anna     28       2020
# 1    Ben     35       2015
# 2  Clara     22       2023
# 3  David     41       2010
# 4    Eva     50       2020

# %% [markdown]
# #### Übung: Erstelle ein einfaches DataFrame und als df1 speichern
# ![Screenshot 2026-09-05 at 10.19.28.png](data:image/png;base64,...)

# %%
# Grundlegende Exploration
print(df.head())
# Out:
#     Name  Alter  Startjahr
# 0   Anna     28       2020
# 1    Ben     35       2015
# 2  Clara     22       2023
# 3  David     41       2010
# 4    Eva     50       2020

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Alter      5 non-null      int64
#  2   Startjahr  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes
# None

# %%
print(df.describe())
# Out:
#           Alter    Startjahr
# count   5.00000     5.000000
# mean   35.20000  2017.600000
# std    10.94075     5.128353
# min    22.00000  2010.000000
# 25%    28.00000  2015.000000
# 50%    35.00000  2020.000000
# 75%    41.00000  2020.000000
# max    50.00000  2023.000000

# %%
# Daten filtern
print(df[df["Alter"] > 30])
# Out:
#     Name  Alter  Startjahr
# 1    Ben     35       2015
# 3  David     41       2010
# 4    Eva     50       2020

# %%
# Neue Spalte hinzufügen
df["Erfahrung_Jahre"] = 2025 - df["Startjahr"]
print(df)
# Out:
#     Name  Alter  Startjahr  Erfahrung_Jahre
# 0   Anna     28       2020                5
# 1    Ben     35       2015               10
# 2  Clara     22       2023                2
# 3  David     41       2010               15
# 4    Eva     50       2020                5

# %%
# Wie viele unterschiedliche Werte hat jede Spalte? → nunique()
df.nunique()

# %%
# Wie viele unterschiedliche Werte in einer Spalte? → unique()
df['Startjahr'].unique()

# %%
# Wie oft kommt jeder einzelne Wert in einer Spalte vor? → value_counts()
df['Startjahr'].value_counts()

# %%
# Durchschnitt berechnen
print("Durchschnittsalter:", df["Alter"].mean())
# Out:
# Durchschnittsalter: 35.2

# %%
# Spalten sortieren
df.sort_values(by="Alter", ascending=False)
# Out:
#     Name  Alter  Startjahr  Erfahrung_Jahre
# 4    Eva     50       2020                5
# 3  David     41       2010               15
# 1    Ben     35       2015               10
# 0   Anna     28       2020                5
# 2  Clara     22       2023                2

# %%
# Spalten umbenennen
df.rename(columns={
    "Name": "Vorname",
    "Alter": "Alter_Jahre"
}, inplace=True)

# %%
# Tabellen anhängen (Append / Concat)
df_neu = pd.DataFrame({
    "Vorname": ["Eva", "Clara"],
    "Alter_Jahre": [29, 22],
    "Startjahr": [2024, 2023]
})

df_all = pd.concat([df, df_neu], ignore_index=True)
print(df_all)
# Out:
#   Vorname  Alter_Jahre  Startjahr  Erfahrung_Jahre
# 0    Anna           28       2020              5.0
# 1     Ben           35       2015             10.0
# 2   Clara           22       2023              2.0
# 3   David           41       2010             15.0
# 4     Eva           50       2020              5.0
# 5     Eva           29       2024              NaN
# 6   Clara           22       2023              NaN

# %%
# Behandlungen der Fehlende Werte
# Variante 1: Fehlende Werte mit einer festen Zahl auffüllen
df_all['Erfahrung_Jahre'] = df_all['Erfahrung_Jahre'].fillna(0)

# Variante 2: Fehlende Werte mit dem Durchschnitt auffüllen
df_all['Erfahrung_Jahre'] = df_all['Erfahrung_Jahre'].fillna(df_all['Erfahrung_Jahre'].mean())

# Variante 3: Einen einzelnen Wert manuell eingeben (Zeile + Spalte auswählen)
df_all.loc[5, 'Erfahrung_Jahre'] = 6

# Alternative zu Variante 3, schneller für eine einzelne Zelle:
df_all.at[6, 'Erfahrung_Jahre'] = 2

# %%
# Duplikate anzeigen
df_all.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
# Duplikate entfernen
df_clean = df_all.drop_duplicates()

# %%
# Optional (nur nach Name)
df.drop_duplicates(subset=["Vorname"])
# Out:
#   Vorname  Alter_Jahre  Startjahr  Erfahrung_Jahre
# 0    Anna           28       2020                5
# 1     Ben           35       2015               10
# 2   Clara           22       2023                2
# 3   David           41       2010               15
# 4     Eva           50       2020                5

# %% [markdown]
# #### Übung: Berechnen das Durchsnitt von Spalte "Total Asset Value" von df1

# %% [markdown]
# ### Daten aus einer CSV-Datei laden
#
# Lade die Datei people.csv aus Notion herunter und speichere sie auf deinem Desktop.

# %%
# CSV-Datei laden
df_people = pd.read_csv("https://raw.githubusercontent.com/chiaoya/Deep-Learning-Foundations-Python-Tensorflow/refs/heads/main/data/py_people.csv")

# %%
df_people
# Out:
#    FirstName LastName  Alter  Startjahr
# 0       Paul   Wagner     44       2018
# 1       Emma     Wolf     27       2010
# 2        Max  Schäfer     44       2024
# 3       Anna    Bauer     24       2001
# 4       Paul     Wolf     27       2009
# ..       ...      ...    ...        ...
# 95      Paul  Richter     55       2008
# 96      Leon    Weber     55       2003
# 97       Ben    Weber     20       2003
# 98      Leon   Wagner     29       2022
# 99     Julia   Müller     22       2013
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Übung
#
# - Gib mit print() die ersten und die letzten 10 Zeilen aus
#
# - Filtere die Daten: Personen, die jünger als 40 Jahre sind
#
# - Berechne den Durchschnitt des Alters
#
# - Wie viele unterschiedliche Werte hat jede Spalte?
#
# - Wie viele Leute haben im Jahr 2003 angefangen?
#
# - Ändere das Alter von Ben Weber auf 30.

# %% [markdown]
# ### 💡 Optional Challenge

# %%
# Sortiere nach Alter
df.sort_values(by="Alter_Jahre", ascending=False)
# Out:
#   Vorname  Alter_Jahre  Startjahr  Erfahrung_Jahre
# 4     Eva           50       2020                5
# 3   David           41       2010               15
# 1     Ben           35       2015               10
# 0    Anna           28       2020                5
# 2   Clara           22       2023                2

# %%
# Zähle, wie viele Personen jünger als 30 sind
df_le30 = df[df["Alter_Jahre"] < 30]
anzahl_1 = len(df_le30)

print("Anzahl der Personen unter 30:", anzahl_1)
# Out:
# Anzahl der Personen unter 30: 2

# %%
# Alternative (noch kompakter)
anzahl_2 = (df["Alter_Jahre"] < 30).sum()
print("Anzahl der Personen unter 30:", anzahl_2)
# Out:
# Anzahl der Personen unter 30: 2

# %%
# Speichere deine Ergebnisse mit
df.to_csv("mein_output.csv", index=False)

# %% [markdown]
# ### 🔗 **Daten zusammenführen (Merge & Join in Pandas)**
#
# **Ziel:**
#
# Verstehen, wie man mehrere Tabellen anhand gemeinsamer Spalten zusammenführt (wie in Excel VLOOKUP oder SQL JOIN).

# %% [markdown]
# **Wichtige Methode:**
#
# pd.merge(df1, df2, on="gemeinsame_Spalte", **how**="inner")

# %% [markdown]
# `how` kann sein:
#
# - `"inner"` – nur gemeinsame Werte (Standard)
# - `"left"` – alle aus der linken Tabelle
# - `"right"` – alle aus der rechten Tabelle
# - `"outer"` – alle Werte, auch wenn sie nicht übereinstimmen

# %%
import pandas as pd

# Erste Tabelle: Personen
personen = pd.DataFrame({
    "Name": ["Anna", "Ben", "Clara", "David"],
    "Abteilungs_ID": [1, 2, 2, 3]
})

# Zweite Tabelle: Abteilungen
abteilungen = pd.DataFrame({
    "Abteilungs_ID": [1, 2, 3],
    "Abteilung": ["HR", "Data", "Marketing"]
})

# Tabellen zusammenführen
merged = pd.merge(personen, abteilungen, on="Abteilungs_ID", how="inner")

print("➡️ Ergebnis:")
print(merged)
# Out:
# ➡️ Ergebnis:
#     Name  Abteilungs_ID  Abteilung
# 0   Anna              1         HR
# 1    Ben              2       Data
# 2  Clara              2       Data
# 3  David              3  Marketing

# %% [markdown]
# ### **Aufgabe:**
#
# **Dauer:** ca. 15 min
#
# 1. Erstelle zwei kleine Tabellen (DataFrame) und führe sie zusammen.
#
# 1️⃣ **employees**
#
# | Name | Dept_ID | Jahr |
# | --- | --- | --- |
# | Alex | 1 | 2020 |
# | Bea | 2 | 2019 |
# | Carl | 3 | 2022 |
# | Diana | 4 | 2021 |
#
# #
#
# 2️⃣ **departments**
#
# | Dept_ID | Department | Ort |
# | --- | --- | --- |
# | 1 | HR | Berlin |
# | 2 | Data | Hamburg |
# | 3 | Marketing | München |

# %% [markdown]
# 2. Übung mit vorbereiteten Daten

# %%
# Lade Daten Datei
employees = pd.read_csv("https://raw.githubusercontent.com/chiaoya/Deep-Learning-Foundations-Python-Tensorflow/refs/heads/main/data/py_employees.csv")
departments = pd.read_csv("https://raw.githubusercontent.com/chiaoya/Deep-Learning-Foundations-Python-Tensorflow/refs/heads/main/data/py_departments.csv")

# %%
# employees

# %%
# departments

# %%
# Erstelle die zwei Tabellen als zwei pandas DataFrame

# Zusammenführen
merged_df = pd.merge(employees, departments, on="Dept_ID", how="inner")

# Zeige erste Zeilen
print(merged_df.head())

# Optional: Berechne das Durchschnittsalter oder gruppiere nach Department
# Out:
#     Name  Dept_ID  Jahr Department        Ort
# 0   Alex        1  2020         HR     Berlin
# 1    Bea        2  2019       Data    Hamburg
# 2   Carl        3  2022  Marketing    München
# 3  Diana        4  2021    Finance  Frankfurt
# 4  Ethan        5  2018         IT  Stuttgart

# %% [markdown]
# ### 💡 Optional Challenge

# %% [markdown]
# 1. Teste verschiedene Join-Typen und vergleichen

# %%
# how="left"
pd.merge(employees, departments, on="Dept_ID", how="left")
# Out:
#        Name  Dept_ID  Jahr  Department         Ort
# 0      Alex        1  2020          HR      Berlin
# 1       Bea        2  2019        Data     Hamburg
# 2      Carl        3  2022   Marketing     München
# 3     Diana        4  2021     Finance   Frankfurt
# 4     Ethan        5  2018          IT   Stuttgart
# 5     Fiona        6  2020  Operations  Düsseldorf
# 6    George        7  2017       Sales        Köln
# 7    Hannah        8  2023       Legal     Leipzig
# 8       Ian        1  2019          HR      Berlin
# 9     Julia        2  2021        Data     Hamburg
# 10    Kevin        3  2016   Marketing     München
# 11    Laura        4  2022     Finance   Frankfurt
# 12     Mike        5  2020          IT   Stuttgart
# 13     Nina        6  2018  Operations  Düsseldorf
# 14    Oscar        7  2021       Sales        Köln
# 15    Paula        8  2019       Legal     Leipzig
# 16  Quentin        1  2023          HR      Berlin
# 17     Rita        2  2017        Data     Hamburg
# 18      Sam        3  2020   Marketing     München
# 19     Tina        4  2022     Finance   Frankfurt
# 20      Uwe        5  2019          IT   Stuttgart
# 21     Vera        6  2021  Operations  Düsseldorf
# 22     Will        7  2018       Sales        Köln
# 23    Xenia        8  2020       Legal     Leipzig
# 24    Yusuf        1  2016          HR      Berlin
# 25     Zara        2  2022        Data     Hamburg
# 26    Aaron        3  2023   Marketing     München
# 27   Bianca        4  2017     Finance   Frankfurt
# 28    Chris        5  2021          IT   Stuttgart
# 29  Daniela        6  2020  Operations  Düsseldorf

# %%
# how="outer"
pd.merge(employees, departments, on="Dept_ID", how="outer")
# Out:
#        Name  Dept_ID  Jahr  Department         Ort
# 0      Alex        1  2020          HR      Berlin
# 1       Ian        1  2019          HR      Berlin
# 2   Quentin        1  2023          HR      Berlin
# 3     Yusuf        1  2016          HR      Berlin
# 4       Bea        2  2019        Data     Hamburg
# 5     Julia        2  2021        Data     Hamburg
# 6      Rita        2  2017        Data     Hamburg
# 7      Zara        2  2022        Data     Hamburg
# 8      Carl        3  2022   Marketing     München
# 9     Kevin        3  2016   Marketing     München
# 10      Sam        3  2020   Marketing     München
# 11    Aaron        3  2023   Marketing     München
# 12    Diana        4  2021     Finance   Frankfurt
# 13    Laura        4  2022     Finance   Frankfurt
# 14     Tina        4  2022     Finance   Frankfurt
# 15   Bianca        4  2017     Finance   Frankfurt
# 16    Ethan        5  2018          IT   Stuttgart
# 17     Mike        5  2020          IT   Stuttgart
# 18      Uwe        5  2019          IT   Stuttgart
# 19    Chris        5  2021          IT   Stuttgart
# 20    Fiona        6  2020  Operations  Düsseldorf
# 21     Nina        6  2018  Operations  Düsseldorf
# 22     Vera        6  2021  Operations  Düsseldorf
# 23  Daniela        6  2020  Operations  Düsseldorf
# 24   George        7  2017       Sales        Köln
# 25    Oscar        7  2021       Sales        Köln
# 26     Will        7  2018       Sales        Köln
# 27   Hannah        8  2023       Legal     Leipzig
# 28    Paula        8  2019       Legal     Leipzig
# 29    Xenia        8  2020       Legal     Leipzig

# %% [markdown]
# 2. Füge neue Spalten hinzu:

# %%
merged_df["Jahre_im_Unternehmen"] = 2025 - merged_df["Jahr"]

# %% [markdown]
# 3. Gruppiere nach Department und berechne den Durchschnitt:

# %%
merged_df.groupby("Department")["Jahre_im_Unternehmen"].mean()
# Out:
# Department
# Data          5.250000
# Finance       4.500000
# HR            5.500000
# IT            5.500000
# Legal         4.333333
# Marketing     4.750000
# Operations    5.250000
# Sales         6.333333
# Name: Jahre_im_Unternehmen, dtype: float64

# %% [markdown]
# ### Diskussionsfragen:
#
# - Was passiert bei „inner“ vs. „outer“ Merge?
#
# - Wo braucht man Merge im echten Leben? (Beispiel: Kundendaten + Bestellungen)
#
# - Wie viele Mitarbeiter, Departments und Arbeitsortㄍ gibt es insgesamt?
